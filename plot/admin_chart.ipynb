# %%
#importando dados e bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv('/home/briqz23/Documents/BeHeart/ddas-21-generator/psychiatric-report-generator/plot/data/mock.csv')
df = pd.DataFrame(data)

# %%
#tratando o df
colunas = ['time_stamp']+[f'pergunta_{str(numero).zfill(2)}' for numero in range(1, 22)] + ['termos','nome', 'cpf','idade','educacao','sexo','estado','trabalho','funcao','mail']
print(len(colunas), data.shape[1])
data.columns = colunas
df.head()
# Out:
# 32 32
#             time_stamp  pergunta_01  pergunta_02  pergunta_03  pergunta_04  \
# 0  18/08/2023 10:23:07            2            1            3            0
# 1  18/08/2023 10:23:07            2            2            3            4
#
#    pergunta_05  pergunta_06  pergunta_07  pergunta_08  pergunta_09  ...  \
# 0            2            1            3            0            2  ...
# 1            2            3            1            2            3  ...
#
#    termos          nome             cpf  idade                       educacao  \
# 0     Sim  Junior Silva  111.111.111-11  19-30  Ensino Fundamental incompleto
# 1     Sim  Marina Silva  333.333.333-11  19-30    Ensino Fundamental completo
#
#         sexo  estado    trabalho      funcao              mail
# 0  Masculino      SP  construtor  Estagiário  daniel@gmail.com
# 1   Feminino      SP  construtor  Estagiário  marina@gmail.com
#
# [2 rows x 32 columns]

# %% [markdown]
# ## Dados demográficos

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

#gráfico idade
count_idade = df['idade'].value_counts()
axs[0].bar(count_idade.index, count_idade.values)
axs[0].set_xlabel('Idades')
axs[0].set_ylabel('Quantidade')
axs[0].set_title('Distribuição das idades')

#gráfico gênero
count_genero = df['genero'].value_counts()
axs[1].bar(count_genero.index, count_genero.values)
axs[1].set_xlabel('Gêneros')
axs[1].set_ylabel('Quantidade')
axs[1].set_title('Distribuição de gêneros')

#gráfico escolaridade
count_escolaridade = df['escolaridade'].value_counts()
axs[2].bar(count_escolaridade.index, count_escolaridade.values)
axs[2].set_xlabel('Níveis de Escolaridade')
axs[2].set_ylabel('Quantidade')
axs[2].set_title('Distribuição das escolaridades')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Análise
